# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
# 指定文件路径
file_path = '/Users/apple/Downloads/final_df.csv'

data = pd.read_csv(file_path)
X = data['Text']
y = data['Result']

print("Text Features:")
print(X)
print("\nTarget (Result):")
print(y)
# Out:
# Text Features:
# 0                                                  forecast
# 1         traveling business meeting take fun trip espec...
# 2                               test test successful way go
# 3         randy send schedule salary level everyone sche...
# 4                                   hello let shoot tuesday
#                                 ...
# 519972    update needed inbox message pending get delete...
# 519973    update needed inbox message pending get delete...
# 519974    staffemployee staffemployee covid vaccine test...
# 519975    notification update notice message sent outsid...
# 519976    accountalert apiupgrade esteem user officially...
# Name: Text, Length: 519977, dtype: object
#
# Target (Result):
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 519972    1
# 519973    1
# 519974    1
# 519975    1
# 519976    1
# Name: Result, Length: 519977, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
file_path = '/Users/apple/Downloads/final_df.csv'
data = pd.read_csv(file_path)
print(data.isnull().sum())
# Out:
# Text      1057
# Result       0
# dtype: int64

# %%
data = data.dropna()

# %%
texts = data['Text']
labels = data['Result']

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_curve, auc, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
model = MultinomialNB()
model.fit(X_resampled, y_resampled)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy after SMOTE:', accuracy_score(y_test, y_pred))
print('Classification Report after SMOTE:\n', classification_report(y_test, y_pred, zero_division=1))
# Out:
# Accuracy after SMOTE: 0.9937755338009713
# Classification Report after SMOTE:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    103304
#            1       0.42      0.95      0.58       480
#
#     accuracy                           0.99    103784
#    macro avg       0.71      0.97      0.79    103784
# weighted avg       1.00      0.99      0.99    103784

# %%
new_texts = ["example text to predict"]
new_X = vectorizer.transform(new_texts)
predictions = model.predict(new_X)
print('Predictions:', predictions)
# Out:
# Predictions: [0]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
import joblib

# 假设你的训练好的模型对象名为 model，例如 MultinomialNB() 或其他模型
model = MultinomialNB()

# 训练模型（假设已经训练完成）

# 将模型保存到文件 'my_model.pkl'
joblib.dump(model, 'my_model.pkl')

# 加载保存的模型
model = joblib.load('my_model.pkl')

# 加载测试数据（假设你有新的邮件内容需要预测）
test_data = pd.read_csv(file_path)  # 替换成你的测试数据文件路径

# 假设测试数据包含 'Text' 列，即邮件内容需要预测
texts_to_predict = test_data['Text']

# 加载训练时使用的 TF-IDF 向量化器进行转换
vectorizer = joblib.load('vectorizer.pkl')  # 替换成你保存的向量化器文件路径
X_test = vectorizer.transform(texts_to_predict)

# 进行预测
predictions = model.predict(X_test)

# 输出预测结果
print('Predictions:')
print(predictions)

# 可选：输出详细的分类报告
print('Classification Report:')
print(classification_report(test_data['Result'], predictions))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[72], line 19
#      16 model = joblib.load('my_model.pkl')
#      18 # 加载测试数据（假设你有新的邮件内容需要预测）
# ---> 19 test_data = pd.read_csv(file_path)  # 替换成你的测试数据文件路径
#      21 # 假设测试数据包含 'Text' 列，即邮件内容需要预测
#      22 texts_to_predict = test_data['Text']
#
# ...
